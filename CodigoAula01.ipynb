# %%
from google.colab import files
import cv2
from google.colab.patches import cv2_imshow

# %%
arquivos = files.upload()

# %%
img = cv2.imread("images.jfif")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]]], dtype=uint8)

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]]

# %%
cv2_imshow(img/2)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
cv2_imshow(img*2)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
cv2_imshow(255-img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
cv2_imshow(255/img)
# Out:
# /tmp/ipykernel_4427/3253987355.py:1: RuntimeWarning: divide by zero encountered in divide
#   cv2_imshow(255/img)
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
cv2_imshow(255*img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
cv2_imshow(255+img)
# Out:
# <PIL.Image.Image image mode=RGB size=360x516>

# %%
B,G,R = cv2.split(img)
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=360x516>
# <PIL.Image.Image image mode=L size=360x516>
# <PIL.Image.Image image mode=L size=360x516>
